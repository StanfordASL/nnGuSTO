# %%
include("astrobee_se3_script.jl")
using Plots
using JLD2, FileIO
using HDF5
using Keras
using Polynomials
using Statistics
using StatsPlots
# Out:
# ┌ Info: CUDAdrv.jl failed to initialize, GPU functionality unavailable (set JULIA_CUDA_SILENT or JULIA_CUDA_VERBOSE to silence or expand this message)
# └ @ CUDAdrv /home/somrita/.julia/packages/CUDAdrv/3EzC1/src/CUDAdrv.jl:69

# %% [markdown]
# # Helper functions

# %% [markdown]
# ## Main GuSTO function

# %%
function solve_gusto(model, N, MAX_ITERATIONS_NB, verbose = true, Xp = [], Up = [])
    
    if (Xp == [] && Up == [])
        Xp,Up = initialize_trajectory(model, N)
    elseif Up == []
        println("GuSTO X has been warm-started.")
        Up = zeros(model.u_dim, N-1)
    else
        if verbose
            println("GuSTO has been warm-started.")
        end
    end
    X, U  = copy(Xp)  , copy(Up) 

    SCPproblem = GuSTOProblem(model, N, Xp, Up)

    x_dim, u_dim = model.x_dim, model.u_dim

    Delta0, omega0, omegamax, 
        epsilon, rho0, rho1, 
        beta_succ, beta_fail, gamma_fail, 
        convergence_threshold = get_initial_gusto_parameters(model)

    Delta = Delta0
    omega = omega0

    X_all, U_all = [], []
    push!(X_all, copy(X))
    push!(U_all, copy(U))

    B_success = false
    it = 0

    while it<MAX_ITERATIONS_NB && 
            !(it!=0 && B_success && 
                convergence_metric(model,X,U,Xp,Up)<convergence_threshold) &&
            omega<omegamax
        if verbose
            println("-----------")
            println("Iteration $it")
            println("metric=$(convergence_metric(model,X,U,Xp,Up))")
            println("-----------")
        end

        Xp = copy(X)
        Up = copy(U)

        model.f, model.A, model.B = compute_dynamics(model, Xp, Up)

        reset_problem(SCPproblem, model)
        set_parameters(SCPproblem, model, Xp, Up, omega, Delta)
        define_cost(SCPproblem, model)
        define_constraints(SCPproblem, model)

        JuMP.optimize!(SCPproblem.solver_model)    

        # get solution
        X_sol = JuMP.value.(SCPproblem.X)
        U_sol = JuMP.value.(SCPproblem.U)

        # -----------
        # GuSTO Logic
        if it > 3
            if is_in_trust_region(model, X_sol, U_sol, Xp, Up, Delta)
                rho = accuracy_ratio(SCPproblem, model, X_sol, U_sol, Xp, Up)

                if rho > rho1
                    if verbose
                        println("Reject solution.")
                    end
                    Delta = beta_fail * Delta
                    omega     = omega
                    B_success = false

                else
                    if verbose
                        println("Accept solution.")
                    end
                    X = copy(X_sol)
                    U = copy(U_sol)
                    B_success = true
                    if rho < rho0
                        Delta = min(beta_succ*Delta, Delta0)
                    else
                        Delta = Delta
                    end
                    if satisfies_state_inequality_constraints(SCPproblem, model, X_sol, U_sol, Xp, Up, Delta)
                        omega = omega0
                    else
                        if verbose
                            println("Solution does not satisfy state constraints, increasing omega.")
                        end
                        omega = gamma_fail * omega
                        B_success = false
                    end
                end
            else
                if verbose
                    println("Reject solution (Outside trust region)")
                end
                Delta = Delta
                omega     = gamma_fail * omega
                B_success = false
            end

        else # always accept first solution
            X = copy(X_sol)
            U = copy(U_sol)
        end


        # -----------

        push!(X_all, copy(X))
        push!(U_all, copy(U))


        it += 1

        diff_with_prev = norm(copy(X) - copy(Xp), Inf)
        if verbose
            println("x(k) - x(k-1) = $diff_with_prev")
            println("Parameters:")
            println("omega=$omega")
            println("delta=$Delta")
        end
    end
    curr_conv_metric = convergence_metric(model,X,U,Xp,Up)
    if (B_success && 
                curr_conv_metric<convergence_threshold)
        if verbose
            println("Converged")
        end
        isConverged = true
    else
        if verbose
            println("Not converged. Metric =$curr_conv_metric")
        end
        isConverged = false
    end
    return isConverged, it, X_all, U_all
end
# Out:
# solve_gusto (generic function with 4 methods)

# %% [markdown]
# ## Function to check if inside obstacle

# %%
function isInsideObstacle(x, model)
    isInside = false
    for obs in model.obstacles
        center = obs[1]
        radius = obs[2]
        if norm(x[1:3] - center) < radius
            isInside = true
            return isInside
        end
    end
    for obs in model.poly_obstacles
        center = obs.c
        dx = obs.dx
        dy = obs.dy
        dz = obs.dz
        x_max = center[1]+dx
        y_max = center[2]+dy
        z_max = center[3]+dz
        x_min = center[1]-dx
        y_min = center[2]-dy
        z_min = center[3]-dz
        if (x[1]<= x_max && x[1] >= x_min && 
            x[2]<= y_max && x[2] >= y_min &&
            x[3]<= z_max && x[3] >= z_min)
            isInside = true
            return isInside
        end
    end
    return isInside
end
# Out:
# isInsideObstacle (generic function with 1 method)

# %% [markdown]
# ## Reading and writing to files

# %%
function getXYValid(filename)
    f = h5open(filename,"r")
    X_valid_norm = read(f["X_valid_norm"])
    Y_valid_norm = read(f["Y_valid_norm"])
    close(f)
    return (X_valid_norm, Y_valid_norm) 
end
# Out:
# getXYValid (generic function with 1 method)

# %%
function getDataParamsFromHDF5Combo(filename)
    f = h5open(filename,"r")
    xMin = read(f["xMin"])
    yMin = read(f["yMin"])
    xRange = read(f["xRange"])
    yRange = read(f["yRange"])
    close(f)
    return (xMin, yMin, xRange, yRange) 
end
# Out:
# getDataParamsFromHDF5Combo (generic function with 1 method)

# %% [markdown]
# ## Get model on which data was collected and training done

# %%
function getModelWithTwoPolyObsOneAtCorner()
    N = 50
    MAX_ITERATIONS_NB = 100

    model = AstrobeeSE3()

    # Set up environment
    model.x_max[1:3] = [10.0; 10.0; 1.0]
    model.x_min[1:3] = [0.0; 0.0; 0.0]

    obstacles = []
    # obs = [[0.0,0.0,0.0], 6.0]
    # push!(obstacles, obs)
    model.obstacles = obstacles

    poly_obstacles = []
    obs = PolygonalObstacle([2.5,2.5,0], [5.0, 5.0, 2.0])
    push!(poly_obstacles, obs)
    obs = PolygonalObstacle([7.0,3.0,0], [1.0, 1.0, 2.0])
    push!(poly_obstacles, obs)
    model.poly_obstacles = poly_obstacles

    model.tf_guess = 110.
    model.convergence_threshold = 5.0 # TODO CHANGED was 2.0
    
    return model
end
# Out:
# getModelWithTwoPolyObsOneAtCorner (generic function with 1 method)

# %%
function findTrueGuSTOSolution(x_init, x_final, model = :None, verbose = false, Xinit = [], Uinit = [])
    N = 50
    MAX_ITERATIONS_NB = 200
    
    if model == :None
        println("No model supplied. Using spheres model.")
        model = getModelWithCornerSpheres()
    end
    
    isConverged = false
    X_all = []
    U_all = []
    numIter = 0

    problemNumber = 0

    train_input_collected = Array{Float64}(undef,0,26)
    train_output_collected = Array{Float64}(undef,0,944)

    if isInsideObstacle(x_init, model)
        println("x_init is inside an obstacle. Not valid.")
        return model, isConverged, X_all, U_all
    end
    if isInsideObstacle(x_final, model)
        println("x_final is inside an obstacle. Not valid.")
        return model, isConverged, X_all, U_all
    end
    if norm(x_final[1:3] - x_init[1:3])<1.0
        println("x_init and x_final too close. Not valid.")
        return model, isConverged, X_all, U_all
    end


    model.x_init = x_init
    model.x_final = x_final
    
    if verbose
        println("Starting to solve GuSTO")
    end
    try
        isConverged, numIter, X_all, U_all = solve_gusto(model, N, MAX_ITERATIONS_NB, verbose, Xinit, Uinit)
    catch e
        isConverged = false
        println("$e")
    end
    if verbose
        println("Converged: $isConverged")
    end

    return model, isConverged, numIter, X_all, U_all
end
# Out:
# findTrueGuSTOSolution (generic function with 5 methods)

# %% [markdown]
# ## NN helper functions

# %%
function recoverCoeffsfromNNOutput(NN_output, yMin, yRange)
    output_coeffs = (NN_output.*yRange)+yMin    
    return output_coeffs
end
# Out:
# recoverCoeffsfromNNOutput (generic function with 1 method)

# %%
function recoverXUfromCoeffs(coeffs)
    N = 50
    tf_guess = 110.
    t_array = range(0,stop=tf_guess,length=N)
    t_minus_one_array = t_array[1:end-1]
    num_coeffs = 5
    x_dim = 13
    u_dim = 6
    
    X_soln = zeros(x_dim, N)
    U_soln = zeros(u_dim, N-1)
    
    for dim = 1:x_dim
        cf_this = coeffs[((dim-1)*num_coeffs + 1): (dim*num_coeffs)]
        this_poly = polyval(Poly(cf_this), t_array)
        X_soln[dim, :] = this_poly
    end
    
    for dim = 1:u_dim
        cf_this = coeffs[(x_dim*num_coeffs + (dim-1)*num_coeffs + 1): (x_dim*num_coeffs + dim*num_coeffs)]
        this_poly = polyval(Poly(cf_this), t_minus_one_array)
        U_soln[dim, :] = this_poly
    end
    
    return X_soln, U_soln
end
# Out:
# recoverXUfromCoeffs (generic function with 1 method)

# %%
function recoverXUfromNNOutput(NN_output, yMin, yRange)
    outputCoeffs = recoverCoeffsfromNNOutput(NN_output, yMin, yRange)
    X_soln, U_soln = recoverXUfromCoeffs(outputCoeffs)
end
# Out:
# recoverXUfromNNOutput (generic function with 1 method)

# %%
function createNNInput(x_init, x_final, xMin, xRange)
    # x_init and x_goal need to be of size 13
    NN_input = hcat([x_init', x_final']...)'
    NN_input = (NN_input-xMin)./xRange
    return NN_input
end
# Out:
# createNNInput (generic function with 1 method)

# %%
function getNNStructureCombo(NNDualParams, NNDualJSON, NNDualWeights)
    (xMin, yMin, xRange, yRange) = getDataParamsFromHDF5Combo(NNDualParams)
    NN = Keras.load(NNDualJSON, NNDualWeights)
    return (NN, xMin, yMin, xRange, yRange)  
end
# Out:
# getNNStructureCombo (generic function with 1 method)

# %%
function getNNPredictionCombo(x_init, x_final, NNDualParams, NNDualJSON, NNDualWeights)
    # x_init and x_goal need to be of size 13
    (NN, xMin, yMin, xRange, yRange) = getNNStructureCombo(NNDualParams, NNDualJSON, NNDualWeights)
    NN_input = zeros(1,26)
    NN_input = createNNInput(x_init, x_final, xMin, xRange)
    NN_output = NN(NN_input)
    X_soln, U_soln = recoverXUfromNNOutput(NN_output, yMin, yRange)
    return (X_soln, U_soln)
end
# Out:
# getNNPredictionCombo (generic function with 1 method)

# %% [markdown]
# # Compare cold start and warm start GuSTO performance

# %% [markdown]
# ### Collect the iteration number and times for each

# %%
x_dim = 13
u_dim = 6
num_coeffs = 5

filename = "PolyComboCoeffsNormalized.jld2"
paramsFileName = "PolyComboParams.h5"
jsonFileName = "SimpleAstrobeeTemplate.json"
weightsFileName = "PolyComboWeights.h5"
(X_valid_norm, Y_valid_norm)  =getXYValid(filename)
X_valid_norm = X_valid_norm'
Y_valid_norm = Y_valid_norm'
# @show size(X_valid_norm)
# @show size(Y_valid_norm)

cold_start_data = zeros(size(X_valid_norm,1), 3)
# NOTE: cold_start_data[row,:] = [converged?, num_iter, solve_time]

warm_start_data = zeros(size(X_valid_norm,1), 3)
# NOTE: warm_start_data[row,:] = [converged?, num_iter, solve_time]

NN_run_data = zeros(size(X_valid_norm,1),1)
# NOTE: NN_run_data[row,:] = NN_solve_time

for row in 1:size(X_valid_norm,1)
# for row in 3:4
    @show row
    # For the X_valid_norm, pass each to a NN and get the Xsoln, Usoln 
    x_v_norm = X_valid_norm[row,:] # size 26
    # First convert to X_valid
    (xMin, yMin, xRange, yRange) = getDataParamsFromHDF5Combo(paramsFileName)
    x_v = x_v_norm.*xRange + xMin
    x_init = x_v[1:13]
    x_final = x_v[14:26]
    
    model = getModelWithTwoPolyObsOneAtCorner()

    # GuSTO solution time and trajectory
    time_start = time_ns()
    model, isConverged, numIter, X_all_true, U_all_true = findTrueGuSTOSolution(x_init, x_final, model, false)
    gusto_solve_time = (time_ns() - time_start)/10^9
    cold_start_data[row,:]= [isConverged, numIter, gusto_solve_time]
    println("GuSTO solve time = $gusto_solve_time ($numIter iterations)")

    # NN prediction time and trajectory
    time_start = time_ns()
    X_soln_NN , U_soln_NN = getNNPredictionCombo(x_init, x_final, paramsFileName, jsonFileName, weightsFileName)
    NN_solve_time = (time_ns() - time_start)/10^9
    NN_run_data[row,1]= NN_solve_time
    @show NN_solve_time

    # GuSTO warm start solution time and trajectory
    time_start = time_ns()
    model, isConverged, numIter_warm, X_all_warm, U_all_warm  = findTrueGuSTOSolution(x_init, x_final, model, false, X_soln_NN, U_soln_NN)
    gusto_warm_solve_time = (time_ns() - time_start)/10^9
    warm_start_data[row,:]= [isConverged, numIter_warm, gusto_warm_solve_time]
    println("GuSTO warm started solve time = $gusto_warm_solve_time ($numIter_warm iterations)")
    
    println("")

#     plot_three_comp(model, [X_all_true[end], X_soln_NN, X_all_warm[end]], ["True GuSTO solution", "NN prediction", "GuSTO solution warm-started with NN prediction"])

    
    
    
#     # NN prediction time and trajectory
#     NN_coeffs = getNNCoeffsCombo(x_init, x_final, paramsFileName, jsonFileName, weightsFileName)
# #     @show size(NN_coeffs)

#     # For the Y_valid_norm, these are 95 coefficients
#     y_v_norm = Y_valid_norm[row,:] # size 95
#     # First convert to Y_valid
#     (xMin, yMin, xRange, yRange) = getDataParamsFromHDF5Combo(paramsFileName)
#     true_coeffs = y_v_norm.*yRange + yMin
# #     @show size(true_coeffs)

#     for dim in 1:(x_dim+u_dim)
#         true_cf_this = true_coeffs[((dim-1)*num_coeffs + 1): (dim*num_coeffs)]
#         NN_cf_this = NN_coeffs[((dim-1)*num_coeffs + 1): (dim*num_coeffs)]
#         true_coeffs_matrix[row,dim,:] = true_cf_this
#         NN_coeffs_matrix[row,dim,:] = NN_cf_this
#     end
    if mod(row,10) == 0
        @save "coldstartwarmstartdataAdjusted.jld2" cold_start_data warm_start_data NN_run_data
        println("Intermediate save")
        println("")
    end
end
@save "coldstartwarmstartdataAdjusted.jld2" cold_start_data warm_start_data NN_run_data
print("All GuSTO warm start, cold start and NN run times are saved")
# Out:
# row = 1
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# GuSTO solve time = 36.533114983 (8 iterations)
# NN_solve_time = 3.37882566
# GuSTO warm started solve time = 6.492320536 (11 iterations)
#
# row = 2
# GuSTO solve time = 4.252091639 (8 iterations)
# NN_solve_time = 0.002097463
# GuSTO warm started solve time = 3.954167501 (7 iterations)
#
# row = 3
# GuSTO solve time = 3.084802644 (5 iterations)
# NN_solve_time = 0.001933763
# GuSTO warm started solve time = 3.594957431 (5 iterations)
#
# row = 4
# GuSTO solve time = 2.902977438 (5 iterations)
# NN_solve_time = 0.002447756
# GuSTO warm started solve time = 2.642460365 (5 iterations)
#
# row = 5
# GuSTO solve time = 2.746397726 (5 iterations)
# NN_solve_time = 0.005509472
# GuSTO warm started solve time = 2.643778767 (5 iterations)
#
# row = 6
# GuSTO solve time = 2.775553721 (5 iterations)
# NN_solve_time = 0.017641626
# GuSTO warm started solve time = 2.70012587 (5 iterations)
#
# row = 7
# GuSTO solve time = 2.812172752 (5 iterations)
# NN_solve_time = 0.011083667
# GuSTO warm started solve time = 2.479526574 (5 iterations)
#
# row = 8
# GuSTO solve time = 2.770529595 (5 iterations)
# NN_solve_time = 0.002351255
# GuSTO warm started solve time = 2.928168878 (5 iterations)
#
# row = 9
# GuSTO solve time = 13.245034997 (22 iterations)
# NN_solve_time = 0.002501325
# GuSTO warm started solve time = 7.309272598 (12 iterations)
#
# row = 10
# GuSTO solve time = 2.797592027 (5 iterations)
# NN_solve_time = 0.002515622
# GuSTO warm started solve time = 3.6750006 (6 iterations)
#
# Intermediate save
#
# row = 11
# GuSTO solve time = 3.324853223 (5 iterations)
# NN_solve_time = 0.002049415
# GuSTO warm started solve time = 2.949916812 (5 iterations)
#
# row = 12
# GuSTO solve time = 6.444947032 (10 iterations)
# NN_solve_time = 0.001981792
# GuSTO warm started solve time = 4.468492935 (7 iterations)
#
# row = 13
# GuSTO solve time = 3.034734073 (5 iterations)
# NN_solve_time = 0.010044518
# GuSTO warm started solve time = 2.627891689 (5 iterations)
#
# row = 14
# GuSTO solve time = 3.475031249 (6 iterations)
# NN_solve_time = 0.00193877
# GuSTO warm started solve time = 2.743070709 (5 iterations)
#
# row = 15
# GuSTO solve time = 4.668029866 (8 iterations)
# NN_solve_time = 0.002075018
# GuSTO warm started solve time = 3.44253935 (6 iterations)
#
# row = 16
# GuSTO solve time = 2.605085527 (5 iterations)
# NN_solve_time = 0.002107699
# GuSTO warm started solve time = 3.624197032 (6 iterations)
#
# row = 17
# GuSTO solve time = 2.929952897 (5 iterations)
# NN_solve_time = 0.002365125
# GuSTO warm started solve time = 2.637125543 (5 iterations)
#
# row = 18
# GuSTO solve time = 2.876570182 (5 iterations)
# NN_solve_time = 0.001986848
# GuSTO warm started solve time = 2.717374355 (5 iterations)
#
# row = 19
# GuSTO solve time = 2.932961783 (5 iterations)
# NN_solve_time = 0.002004611
# GuSTO warm started solve time = 2.566319911 (5 iterations)
#
# row = 20
# GuSTO solve time = 3.349799593 (6 iterations)
# NN_solve_time = 0.002370071
# GuSTO warm started solve time = 4.677860246 (8 iterations)
#
# Intermediate save
#
# row = 21
# GuSTO solve time = 3.048331329 (5 iterations)
# NN_solve_time = 0.002836764
# GuSTO warm started solve time = 2.831217094 (5 iterations)
#
# row = 22
# GuSTO solve time = 2.874143611 (5 iterations)
# NN_solve_time = 0.002074598
# GuSTO warm started solve time = 3.35209845 (6 iterations)
#
# row = 23
# GuSTO solve time = 2.718841854 (5 iterations)
# NN_solve_time = 0.001990951
# GuSTO warm started solve time = 2.637604469 (5 iterations)
#
# row = 24
# GuSTO solve time = 3.269816691 (6 iterations)
# NN_solve_time = 0.00213623
# GuSTO warm started solve time = 4.574140891 (8 iterations)
#
# row = 25
# GuSTO solve time = 2.922575654 (5 iterations)
# NN_solve_time = 0.012480179
# GuSTO warm started solve time = 2.829886532 (5 iterations)
#
# row = 26
# GuSTO solve time = 2.844047817 (5 iterations)
# NN_solve_time = 0.002085578
# GuSTO warm started solve time = 2.733993097 (5 iterations)
#
# row = 27
# GuSTO solve time = 3.391311361 (6 iterations)
# NN_solve_time = 0.002338124
# GuSTO warm started solve time = 5.533544908 (9 iterations)
#
# row = 28
# GuSTO solve time = 2.759718786 (5 iterations)
# NN_solve_time = 0.002049352
# GuSTO warm started solve time = 3.188598164 (5 iterations)
#
# row = 29
# GuSTO solve time = 2.763958507 (5 iterations)
# NN_solve_time = 0.009302368
# GuSTO warm started solve time = 2.559451441 (5 iterations)
#
# row = 30
# GuSTO solve time = 3.451969851 (6 iterations)
# NN_solve_time = 0.001843332
# GuSTO warm started solve time = 4.727259782 (8 iterations)
#
# Intermediate save
#
# row = 31
# GuSTO solve time = 2.740005938 (5 iterations)
# NN_solve_time = 0.002072928
# GuSTO warm started solve time = 2.881992068 (5 iterations)
#
# row = 32
# GuSTO solve time = 2.762643178 (5 iterations)
# NN_solve_time = 0.001974965
# GuSTO warm started solve time = 2.880190508 (5 iterations)
#
# row = 33
# GuSTO solve time = 3.379832877 (6 iterations)
# NN_solve_time = 0.002001002
# GuSTO warm started solve time = 2.601214539 (5 iterations)
#
# row = 34
# GuSTO solve time = 2.925993768 (5 iterations)
# NN_solve_time = 0.002042709
# GuSTO warm started solve time = 2.764487002 (5 iterations)
#
# row = 35
# GuSTO solve time = 2.85322416 (5 iterations)
# NN_solve_time = 0.003467093
# GuSTO warm started solve time = 2.576281867 (5 iterations)
#
# row = 36
# GuSTO solve time = 2.857523522 (5 iterations)
# NN_solve_time = 0.002003524
# GuSTO warm started solve time = 2.771201097 (5 iterations)
#
# row = 37
# GuSTO solve time = 3.467984809 (6 iterations)
# NN_solve_time = 0.002007159
# GuSTO warm started solve time = 2.992024608 (5 iterations)
#
# row = 38
# GuSTO solve time = 4.617811222 (8 iterations)
# NN_solve_time = 0.011857934
# GuSTO warm started solve time = 4.395134015 (8 iterations)
#
# row = 39
# GuSTO solve time = 2.971775096 (5 iterations)
# NN_solve_time = 0.009776159
# GuSTO warm started solve time = 3.533470688 (6 iterations)
#
# row = 40
# GuSTO solve time = 2.552681904 (5 iterations)
# NN_solve_time = 0.001936267
# GuSTO warm started solve time = 2.885364805 (5 iterations)
#
# Intermediate save
#
# row = 41
# GuSTO solve time = 11.038994975 (18 iterations)
# NN_solve_time = 0.002099172
# GuSTO warm started solve time = 8.20013261 (14 iterations)
#
# row = 42
# GuSTO solve time = 2.856697339 (5 iterations)
# NN_solve_time = 0.001896756
# GuSTO warm started solve time = 2.730059917 (5 iterations)
#
# row = 43
# GuSTO solve time = 4.437640178 (8 iterations)
# NN_solve_time = 0.00344896
# GuSTO warm started solve time = 4.374600959 (7 iterations)
#
# row = 44
# GuSTO solve time = 2.934288435 (5 iterations)
# NN_solve_time = 0.001967377
# GuSTO warm started solve time = 2.782643819 (5 iterations)
#
# row = 45
# GuSTO solve time = 2.845698052 (5 iterations)
# NN_solve_time = 0.0019492
# GuSTO warm started solve time = 2.985041832 (5 iterations)
#
# row = 46
# GuSTO solve time = 3.554373371 (5 iterations)
# NN_solve_time = 0.00278169
# GuSTO warm started solve time = 3.325965213 (5 iterations)
#
# row = 47
# GuSTO solve time = 4.222789298 (6 iterations)
# NN_solve_time = 0.001987968
# GuSTO warm started solve time = 2.860967246 (5 iterations)
#
# row = 48
# GuSTO solve time = 3.134458971 (6 iterations)
# NN_solve_time = 0.002085256
# GuSTO warm started solve time = 2.916075813 (5 iterations)
#
# row = 49
# GuSTO solve time = 2.5946993 (5 iterations)
# NN_solve_time = 0.002205814
# GuSTO warm started solve time = 2.901467692 (5 iterations)
#
# row = 50
# GuSTO solve time = 2.791349452 (5 iterations)
# NN_solve_time = 0.002006959
# GuSTO warm started solve time = 3.585722638 (6 iterations)
#
# Intermediate save
#
# row = 51
# GuSTO solve time = 3.058070232 (5 iterations)
# NN_solve_time = 0.002207766
# GuSTO warm started solve time = 2.679664481 (5 iterations)
#
# row = 52
# GuSTO solve time = 3.039414751 (5 iterations)
# NN_solve_time = 0.030052064
# GuSTO warm started solve time = 3.337429256 (5 iterations)
#
# row = 53
# GuSTO solve time = 3.951897035 (7 iterations)
# NN_solve_time = 0.00213909
# GuSTO warm started solve time = 3.549450343 (6 iterations)
#
# row = 54
# GuSTO solve time = 2.527681338 (5 iterations)
# NN_solve_time = 0.00219583
# GuSTO warm started solve time = 2.840615877 (5 iterations)
#
# row = 55
# GuSTO solve time = 2.920134057 (5 iterations)
# NN_solve_time = 0.002153858
# GuSTO warm started solve time = 2.739133592 (5 iterations)
#
# row = 56
# GuSTO solve time = 9.049764661 (15 iterations)
# NN_solve_time = 0.002378297
# GuSTO warm started solve time = 5.611743693 (9 iterations)
#
# row = 57
# GuSTO solve time = 2.83857148 (5 iterations)
# NN_solve_time = 0.00211567
# GuSTO warm started solve time = 3.04197369 (5 iterations)
#
# row = 58
# GuSTO solve time = 2.498393383 (5 iterations)
# NN_solve_time = 0.001875649
# GuSTO warm started solve time = 2.767611232 (5 iterations)
#
# row = 59
# GuSTO solve time = 3.37500537 (5 iterations)
# NN_solve_time = 0.002657589
# GuSTO warm started solve time = 3.278307131 (5 iterations)
#
# row = 60
# GuSTO solve time = 2.916683134 (5 iterations)
# NN_solve_time = 0.001975281
# GuSTO warm started solve time = 2.557142604 (5 iterations)
#
# Intermediate save
#
# row = 61

# %% [markdown]
# ## Plotting cold and warm start data

# %%
@load "coldstartwarmstartdataAdjusted.jld2" cold_start_data warm_start_data NN_run_data
# Out:
# 3-element Array{Symbol,1}:
#  :cold_start_data
#  :warm_start_data
#  :NN_run_data

# %%
@show size(cold_start_data)
cold_conv = cold_start_data[:,1]
@show extrema(cold_conv)
warm_conv = warm_start_data[:,1]
@show extrema(warm_conv)
# Out:
# size(cold_start_data) = (1130, 3)
# extrema(cold_conv) = (0.0, 1.0)
# extrema(warm_conv) = (0.0, 1.0)
# (0.0, 1.0)

# %%
for row = 1:size(cold_start_data,1)
    if warm_conv[row] == 0.0
        println("didn't converge")
        @show warm_start_data[row,2]
        continue;
    end
end
# Out:
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0
# didn't converge
# warm_start_data[row, 2] = 0.0

# %%
w = warm_start_data
c = cold_start_data
w_filt = [w[i,:] for i=1:size(w,1) if w[i,1]==1 && c[i,1]==1]
c_filt = [c[i,:] for i=1:size(c,1) if w[i,1]==1 && c[i,1]==1]
c_filt = Array(hcat(c_filt...)')
w_filt = Array(hcat(w_filt...)')
# Out:
# 2×3 Array{Float64,2}:
#  1.0  11.0  8.21361
#  1.0   9.0  5.62928

# %%
warm_iter = w_filt[:,2]
cold_iter = c_filt[:,2]
@show mean(warm_iter)
@show mean(cold_iter)
warm_time = w_filt[:,3]
cold_time = c_filt[:,3]
@show mean(warm_time)
@show mean(cold_time)
# Out:
# mean(warm_iter) = 10.0
# mean(cold_iter) = 9.0
# mean(warm_time) = 6.9214428245
# mean(cold_time) = 16.29909683
# 16.29909683

# %%
diff_iter = zeros(size(w_filt,1),2)
diff_iter[:,1] = cold_iter
diff_iter[:,2] = warm_iter
@show mean(cold_iter)
@show mean(warm_iter)
@show median(cold_iter)
@show median(warm_iter)

@show size(diff_iter)
boxplot(["cold" "warm"],diff_iter,leg=false; outliers= false)
plot!(yaxis="no. of iterations")
plot!(xtickfontsize=18, ytickfontsize = 14, grid=true, gridalpha=0.3, guidefontsize = 18)
# title!("Difference between warm start and cold start iterations")
# Out:
# mean(cold_iter) = 9.0
# mean(warm_iter) = 10.0
# median(cold_iter) = 9.0
# median(warm_iter) = 10.0
# size(diff_iter) = (2, 2)

# %%
diff_iter = zeros(size(w_filt,1),2)
diff_iter[:,1] = cold_time
diff_iter[:,2] = warm_time
@show mean(diff_iter[:,1])
@show mean(diff_iter[:,2])

@show size(diff_iter)
boxplot(["cold" "warm"],diff_iter,leg=false; outliers= false)
plot!(yaxis="time(s)")
plot!(xtickfontsize=18, ytickfontsize = 14, grid=true, gridalpha=0.3, guidefontsize = 18)
# title!("Difference between warm start and cold start iterations")
# Out:
# mean(diff_iter[:, 1]) = 16.29909683
# mean(diff_iter[:, 2]) = 6.9214428245
# size(diff_iter) = (2, 2)

# %%
diff_iter = cold_iter - warm_iter
count(x->x==0.0,diff_iter)
# count(x->x<0.0,diff_iter)
# Out:
# 0

# %%
xs = 1:size(w_filt,1)
plot(xs, cold_iter,label="cold")
plot!(xs, warm_iter, label = "warm")

# %%
w_filt_large_iter = [w_filt[i,:] for i=1:size(w_filt,1) if c_filt[i,2]>=10]
c_filt_large_iter = [c_filt[i,:] for i=1:size(c_filt,1) if c_filt[i,2]>=10]
c_filt_large_iter = Array(hcat(c_filt_large_iter...)')
w_filt_large_iter = Array(hcat(w_filt_large_iter...)')
@show size(w_filt_large_iter)
@show size(c_filt_large_iter)
# Out:
# size(w_filt_large_iter) = (1, 3)
# size(c_filt_large_iter) = (1, 3)
# (1, 3)

# %%
diff_iter = zeros(size(w_filt_large_iter,1),2)
diff_iter[:,1] = c_filt_large_iter[:,2]
diff_iter[:,2] = w_filt_large_iter[:,2]
@show mean(diff_iter[:,1])
@show mean(diff_iter[:,2])
@show median(diff_iter[:,1])
@show median(diff_iter[:,2])

@show size(diff_iter)
boxplot(["cold" "warm"],diff_iter,leg=false; outliers= false)
plot!(yaxis="no. of iterations")
plot!(xtickfontsize=18, ytickfontsize = 14, grid=true, gridalpha=0.3, guidefontsize = 18)
# title!("Difference between warm start and cold start iterations")
# Out:
# mean(diff_iter[:, 1]) = 10.0
# mean(diff_iter[:, 2]) = 11.0
# median(diff_iter[:, 1]) = 10.0
# median(diff_iter[:, 2]) = 11.0
# size(diff_iter) = (1, 2)

# %%
w_filt_large_iter = [w_filt[i,:] for i=1:size(w_filt,1) if c_filt[i,2]>6]
c_filt_large_iter = [c_filt[i,:] for i=1:size(c_filt,1) if c_filt[i,2]>6]
c_filt_large_iter = Array(hcat(c_filt_large_iter...)')
w_filt_large_iter = Array(hcat(w_filt_large_iter...)')
@show size(w_filt_large_iter)
@show size(c_filt_large_iter)
# Out:
# size(w_filt_large_iter) = (2, 3)
# size(c_filt_large_iter) = (2, 3)
# (2, 3)

# %%
diff_iter = zeros(size(w_filt_large_iter,1),2)
diff_iter[:,1] = c_filt_large_iter[:,2]
diff_iter[:,2] = w_filt_large_iter[:,2]
@show mean(diff_iter[:,1])
@show mean(diff_iter[:,2])
@show median(diff_iter[:,1])
@show median(diff_iter[:,2])

@show size(diff_iter)
boxplot(["cold" "warm"],diff_iter,leg=false; outliers= false)
plot!(yaxis="no. of iterations")
plot!(xtickfontsize=18, ytickfontsize = 14, grid=true, gridalpha=0.3, guidefontsize = 18)
# title!("Difference between warm start and cold start iterations")
# Out:
# mean(diff_iter[:, 1]) = 9.0
# mean(diff_iter[:, 2]) = 10.0
# median(diff_iter[:, 1]) = 9.0
# median(diff_iter[:, 2]) = 10.0
# size(diff_iter) = (2, 2)
