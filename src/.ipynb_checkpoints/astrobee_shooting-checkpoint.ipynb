# %%
include("astrobee_se3_script.jl")
using Plots

N = 50
MAX_ITERATIONS_NB = 100

model = Astrobee()

Xp,Up = initialize_trajectory(model, N)
X, U  = copy(Xp) .+ 2., copy(Up) .+ 2.

SCPproblem = GuSTOProblem(model, N, Xp, Up)

x_dim, u_dim = model.x_dim, model.u_dim

Delta0, omega0, omegamax, 
    epsilon, rho0, rho1, 
    beta_succ, beta_fail, gamma_fail, 
    convergence_threshold = get_initial_gusto_parameters(model)

Delta = Delta0
omega = omega0

# X = zeros(x_dim, N)
# U = zeros(u_dim, N-1)
println("oh yeah")
# Out:
# oh yeah

# %%
#     problem = Model(with_optimizer(Ipopt.Optimizer, print_level=0))

# %%
gamma_fail
# Out:
# 5.0

# %%
beta_fail
# Out:
# 0.5

# %%
include("astrobee_se3_script.jl")

X_all, U_all, x_shooting_all = [], [], []
push!(X_all, copy(X))
push!(U_all, copy(U))

B_success = false
it = 0

while it<MAX_ITERATIONS_NB && 
        !(it!=0 && it!=1 && it!=2 && it!=3 && B_success && 
            convergence_metric(model,X,U,Xp,Up)<convergence_threshold) &&
        omega<omegamax
    println("-----------")
    println("Iteration $it")
    println("metric=$(convergence_metric(model,X,U,Xp,Up))")
    println("-----------")
    
#     omega, Delta = SCPproblem.omega, SCPproblem.Delta
    
    Xp = copy(X)
    Up = copy(U)
    
    model.f, model.A, model.B = compute_dynamics(model, Xp, Up)
    
    reset_problem(SCPproblem, model)
    set_parameters(SCPproblem, model, Xp, Up, omega, Delta)
    define_cost(SCPproblem, model)
    define_constraints(SCPproblem, model)
    
    JuMP.optimize!(SCPproblem.solver_model)    
    p0 = get_initial_constraint_dual_variable(SCPproblem, model)
    
    # get solution
    X_sol = JuMP.value.(SCPproblem.X)
    U_sol = JuMP.value.(SCPproblem.U)
    
    # try shooting
    #x_shooting, sol_newton = solve_shooting(SCPproblem, model, p0)
#     x_shooting = solve_shooting_once(SCPproblem, model, p0)
    #push!(x_shooting_all, x_shooting)
    
    # -----------
    # GuSTO Logic
    if it > 2
        if is_in_trust_region(model, X_sol, U_sol, Xp, Up, Delta)
            rho = accuracy_ratio(SCPproblem, model, X_sol, U_sol, Xp, Up)

            if rho > rho1
                println("Reject solution.")
                Delta = beta_fail * Delta
                omega     = omega
                B_success = false

            else
                println("Accept solution.")
                X = copy(X_sol)
                U = copy(U_sol)
                B_success = true
                if rho < rho0
                    Delta = min(beta_succ*Delta, Delta0)
                else
                    Delta = Delta
                end
                if satisfies_state_inequality_constraints(SCPproblem, model, X_sol, U_sol, Xp, Up, Delta)
                    omega = omega0
                else
                    println("Solution does not satisfy state constraints, increasing omega.")
                    omega = gamma_fail * omega
                    B_success = false
                end
            end

        else
            println("Reject solution (Outside trust region)")
            Delta = Delta
            omega     = gamma_fail * omega
            B_success = false
        end
    else # always accept first solution
        X = copy(X_sol)
        U = copy(U_sol)
    end
        
                    
    # -----------

    push!(X_all, copy(X))
    push!(U_all, copy(U))
                    
    
    it += 1
    
    println("Parameters:")
    println("omega=$omega")
    println("delta=$Delta")
end
# Out:
# -----------
# Iteration 0
# metric=94.24868789068172
# -----------
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 1
# metric=92.41705808120503
# -----------
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 2
# metric=156.78723769328187
# -----------
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 3
# metric=87.1807371992379
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 4
# metric=224.77512597807325
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 5
# metric=245.8113517352682
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 6
# metric=60.3817796724378
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 7
# metric=52.44483329015121
# -----------
# Accept solution.
# Solution does not satisfy state constraints, increasing omega.
# Parameters:
# omega=5.0
# delta=1000.0
# -----------
# Iteration 8
# metric=27.248546532600717
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 9
# metric=4.764805956118825
# -----------
# Accept solution.
# Solution does not satisfy state constraints, increasing omega.
# Parameters:
# omega=5.0
# delta=1000.0
# -----------
# Iteration 10
# metric=4.368254079216233
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0
# -----------
# Iteration 11
# metric=0.7352064353403536
# -----------
# Accept solution.
# Solution does not satisfy state constraints, increasing omega.
# Parameters:
# omega=5.0
# delta=1000.0
# -----------
# Iteration 12
# metric=0.4608897893960413
# -----------
# Accept solution.
# Parameters:
# omega=1.0
# delta=1000.0

# %%
gamma_fail
# Out:
# 5.0

# %%
include("astrobee_se3_script.jl")

x_shooting, sol_newton = solve_shooting(SCPproblem, model, get_initial_constraint_dual_variable(SCPproblem, model))
x_shooting = solve_shooting_once(SCPproblem, model, sol_newton.zero)
# Out:
# UndefVarError: shooting_ode_func! not defined
#
# Stacktrace:
#  [1] parameterized_shooting_eval!(::Array{Float64,1}, ::GuSTOProblem, ::Astrobee, ::Array{Float64,1}) at /home/freeflyerhub/GuSTO_shooting/jlGuSTO/astrobee_se3_script.jl:79
#  [2] #142 at /home/freeflyerhub/GuSTO_shooting/jlGuSTO/astrobee_se3_script.jl:51 [inlined]
#  [3] (::getfield(NLSolversBase, Symbol("#fj_finitediff!#21")){getfield(Main, Symbol("##142#143")){GuSTOProblem,Astrobee}})(::Array{Float64,1}, ::Array{Float64,2}, ::Array{Float64,1}) at /home/freeflyerhub/.julia/packages/NLSolversBase/NsXIC/src/objective_types/oncedifferentiable.jl:137
#  [4] value_jacobian!!(::OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::Array{Float64,2}, ::Array{Float64,1}) at /home/freeflyerhub/.julia/packages/NLSolversBase/NsXIC/src/interface.jl:124
#  [5] value_jacobian!! at /home/freeflyerhub/.julia/packages/NLSolversBase/NsXIC/src/interface.jl:122 [inlined]
#  [6] trust_region_(::OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Float64, ::Bool, ::NLsolve.NewtonTrustRegionCache{Array{Float64,1}}) at /home/freeflyerhub/.julia/packages/NLsolve/FBwyC/src/solvers/trust_region.jl:119
#  [7] trust_region at /home/freeflyerhub/.julia/packages/NLsolve/FBwyC/src/solvers/trust_region.jl:229 [inlined] (repeats 2 times)
#  [8] #nlsolve#25(::Symbol, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Static, ::getfield(NLsolve, Symbol("##32#34")), ::Float64, ::Bool, ::Int64, ::Int64, ::Int64, ::Int64, ::typeof(nlsolve), ::OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at /home/freeflyerhub/.julia/packages/NLsolve/FBwyC/src/nlsolve/nlsolve.jl:26
#  [9] (::getfield(NLsolve, Symbol("#kw##nlsolve")))(::NamedTuple{(:method, :xtol, :ftol, :iterations, :store_trace, :show_trace, :extended_trace, :linesearch, :factor, :autoscale, :m, :beta, :aa_start, :droptol, :linsolve),Tuple{Symbol,Float64,Float64,Int64,Bool,Bool,Bool,Static,Float64,Bool,Int64,Int64,Int64,Int64,getfield(NLsolve, Symbol("##32#34"))}}, ::typeof(nlsolve), ::OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at ./none:0
#  [10] #nlsolve#30(::Symbol, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Static, ::Float64, ::Bool, ::Int64, ::Int64, ::Int64, ::Int64, ::Symbol, ::getfield(NLsolve, Symbol("##32#34")), ::Bool, ::typeof(nlsolve), ::getfield(Main, Symbol("##142#143")){GuSTOProblem,Astrobee}, ::Array{Float64,1}) at /home/freeflyerhub/.julia/packages/NLsolve/FBwyC/src/nlsolve/nlsolve.jl:73
#  [11] (::getfield(NLsolve, Symbol("#kw##nlsolve")))(::NamedTuple{(:iterations, :ftol),Tuple{Int64,Float64}}, ::typeof(nlsolve), ::Function, ::Array{Float64,1}) at ./none:0
#  [12] solve_shooting(::GuSTOProblem, ::Astrobee, ::Array{Float64,1}) at /home/freeflyerhub/GuSTO_shooting/jlGuSTO/astrobee_se3_script.jl:54
#  [13] top-level scope at In[47]:2

# %%
xN = x_shooting[:,end]

for i = 1:x_dim
    Fi = model.x_final[i] - xN[i]
    @show Fi
end
# Out:
# UndefVarError: x_shooting not defined
#
# Stacktrace:
#  [1] top-level scope at In[48]:1

# %%
    for x_shooting in x_shooting_all
        if size(x_shooting,1) > 1
        @show minimum(x_shooting)
        end
end

# %%
x_shooting_all
# Out:
# 0-element Array{Any,1}

# %%
include("astrobee_se3_script.jl")
#plot(X[1,:],X[2,:])

plot_solutions(SCPproblem, model, X_all[end-1:end], U_all[end-1:end]; x_shooting_all=x_shooting_all)

# %%
X = X_all[end]
# Xs = x_shooting_all[2]
 fig = plot(X[1,:], X[2,:], X[3,:]; c=:blue, lims = (-0.7,0.7))
# plot!(fig, Xs[1,:], Xs[2,:], Xs[3,:]; c=:red)

xlims = (0,10)
zlims = (0,10)
fig

# %%
idx = [1,2]
x = X_all[2][1,:]
y = X_all[2][2,:]
z = X_all[2][3,:]
# plot(x,  y)
plot(1:N, y)
